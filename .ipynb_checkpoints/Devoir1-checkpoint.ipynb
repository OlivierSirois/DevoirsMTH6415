# %%
using JuMP
using Clp
#using ConditionalJuMP
using Distributions
using PyPlot

# %% [markdown]
# # Question 1 : Valeur Optimal vs Variance

# %%
#Mean Case
c = 0.15
q = 0.25
r = 0.02
MeanCase = 650 * (q-c)
#We already know the optimal value of x in the mean case scenario is 650
#we can then assume that we will always buy 650 journal for the optimal mean
#case

#Now for the Stochastic Solution, we can directly use our results from the
#newsvendor problem and adjust it in accordance with the uncertainty (variance)
#we can store all of the optimal stochastic response of our problem
Stoc = Array{Float64}(200)

for i = 1:200
    d = Normal(650, (i))
    Stoc[i] = quantile(d, (q-c)/(q-r))
    #println(i)
end

#println(Stoc)
figure(1)
VSS = (Stoc .* (q-c)) .- MeanCase
plot(Stoc, color="red")
title("Valeur Optimal de x en fonction de l'ecart type")
xlabel("Variance")
ylabel("Valeur Optimale")
figure(2)
plot(VSS, color="blue")
title("Valeur de la Solution Stochastique en fonction de la Variance")
xlabel("Variance")
ylabel("VSS")
show()
# Out:
# PyPlot.Figure(PyObject <matplotlib.figure.Figure object at 0x7f709a77eed0>)
# PyPlot.Figure(PyObject <matplotlib.figure.Figure object at 0x7f709a6e9b90>)

# %% [markdown]
# On peut conclure que l'impact de la variance fait varier l'incertitude de notre second stage. Par contre, l'impact de cette incertitude est affecter par le ratio de profit/perte de nos couts. si nos valeurs de c,r changerait de sorte que c/r augmenterait, la pente de notre courbe augmenterait tandis que l'inverse la ferait diminuer d'avantage.
#
# En ce qui concerne la valeur de la solution stochastique, la valeur de l'esperance ne changerait pas etant donner que la moyenne de notre distribution ne varie pas. La seule chose qui varie est l'ecart-type.

# %% [markdown]
# # Question 2: Monte Carlo

# %% [markdown]
# Pour cette question, nous allons simplement simuler 10^k ou k=1,2,3..6 essaies. Lors de nos essaies, nous allons prendre aleatoirement une decision first stage et second stage. Nous pourrons ensuite representer toutes ces essaies dans une graphe et en interpreter nous-memes les resultats.

# %%
function newvendor(demande::Float64 = 650)
    m= Model(solver = ClpSolver())
    c = 0.15
    q = 0.25
    r = 0.02
    
    
    @variable(m, x >= 0)
    
    @objective(m, Max, 
    (x >= demande ? (q*demande + r(x-demande) - c * x):(x*(q-c))))
    status = solve(m)
    println(getvalue(x))
    return m, status
end
# Out:
# newvendor (generic function with 2 methods)

# %%
m, stat = newvendor(650.0)
# Out:
# MethodError: no method matching isless(::Float64, ::JuMP.Variable)
# Closest candidates are:
#   isless(::Float64, ::Float64) at float.jl:439
#   isless(::PyCall.PyObject, ::Any) at /home/olivier/.julia/v0.6/PyCall/src/pyoperators.jl:71
#   isless(::AbstractFloat, ::AbstractFloat) at operators.jl:96
#   ...
#
# Stacktrace:
#  [1] macro expansion at /home/olivier/.julia/v0.6/JuMP/src/macros.jl:719 [inlined]
#  [2] newvendor(::Float64) at ./In[199]:10
#  [3] include_string(::String, ::String) at ./loading.jl:522

# %% [markdown]
# function secondstage(demande::Float64, x::Int8)
#     c = 0.15
#     q = 0.25
#     r = 0.02
#     if demande >= x
#         return (demande * (q-c))
#     else
#         return (demande * q + (demande - x)*r - x * c)
#     end
# end

# %% [markdown]
# k = 6
# First_Stage = Array{Int}(10^k)
# Profits = Array{Float64}(10^k)
# Ecart_type = 80
# Moyenne = 650
# demand = Normal(Moyenne, Ecart_type)
# upper_x = 850
# lower_x  = 450
#
# c = 0.15
# q = 0.25
# r = 0.02
#
# for i = 1:10^k
#     x = rand(lower_x:upper_x)
#     First_Stage[i] = x
#     d = rand(demand)
#     if (d >= x)
#         Profits[i] = x*(q-c)
#     else
#         Profits[i] = d*q + (x-d)*r - c*x
#     end
#
# end
#
# #xedges = linspace(minimum(First_Stage), maximum(First_Stage), 200)
# #yedges = linspace(minimum(Profits), maximum(Profits), 200)
# #althist(First_Stage, Profits, xedges, yedges)
# #fit_mle(Multinomial, First_Stage, Profits)
